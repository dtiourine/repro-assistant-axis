# %%
from transformer_lens import HookedTransformer

MODEL_NAME = "google/gemma-2-9b-it"
# Out:
# c:\Users\MLDev\anaconda3\envs\transformer-lens\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# c:\Users\MLDev\anaconda3\envs\transformer-lens\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
model = HookedTransformer.from_pretrained(MODEL_NAME)
# Out:
# WARNING:root:You tried to specify center_unembed=True for a model using logit softcap, but this can't be done! Softcapping is not invariant upon adding a constant Setting center_unembed=False instead.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = HookedTransformer.from_pretrained(MODEL_NAME)
#
# File c:\Users\MLDev\anaconda3\envs\transformer-lens\Lib\site-packages\transformer_lens\HookedTransformer.py:1382, in HookedTransformer.from_pretrained(cls, model_name, fold_ln, center_writing_weights, center_unembed, refactor_factored_attn_matrices, checkpoint_index, checkpoint_value, hf_model, device, n_devices, tokenizer, move_to_device, fold_value_biases, default_prepend_bos, default_padding_side, dtype, first_n_layers, **from_pretrained_kwargs)
#    1374 # Create the HookedTransformer object
#    1375 model = cls(
#    1376     cfg,
#    1377     tokenizer,
#    1378     move_to_device=False,
#    1379     default_padding_side=default_padding_side,
#    1380 )
# -> 1382 model.load_and_process_state_dict(
#    1383     state_dict,
#    1384     fold_ln=fold_ln,
#    1385     center_writing_weights=center_writing_weights,
#    1386     center_unembed=center_unembed,
#    1387     fold_value_biases=fold_value_biases,
#    1388     refactor_factored_attn_matrices=refactor_factored_attn_matrices,
#    1389 )
#    1391 if move_to_device:
#    1392     model.move_model_modules_to_device()
#
# File c:\Users\MLDev\anaconda3\envs\transformer-lens\Lib\site-packages\transformer_lens\HookedTransformer.py:1615, in HookedTransformer.load_and_process_state_dict(self, state_dict, fold_ln, center_writing_weights, center_unembed, fold_value_biases, refactor_factored_attn_matrices)
#    1613     state_dict = self.fold_layer_norm(state_dict)
#    1614 elif self.cfg.normalization_type in ["RMS", "RMSPre"]:
# -> 1615     state_dict = self.fold_layer_norm(
#    1616         state_dict, fold_biases=False, center_weights=False
#    1617     )
#    1618 else:
#    1619     logging.warning(
#    1620         "You are not using LayerNorm or RMSNorm, so the layer norm weights can't be folded! Skipping"
#    1621     )
#
# File c:\Users\MLDev\anaconda3\envs\transformer-lens\Lib\site-packages\transformer_lens\HookedTransformer.py:1748, in HookedTransformer.fold_layer_norm(self, state_dict, fold_biases, center_weights)
#    1742     state_dict[f"blocks.{l}.mlp.b_in"] = state_dict[f"blocks.{l}.mlp.b_in"] + (
#    1743         state_dict[f"blocks.{l}.mlp.W_in"]
#    1744         * state_dict[f"blocks.{l}.ln2.b"][:, None]
#    1745     ).sum(-2)
#    1746     del state_dict[f"blocks.{l}.ln2.b"]
# -> 1748 state_dict[f"blocks.{l}.mlp.W_in"] = (
#    1749     state_dict[f"blocks.{l}.mlp.W_in"] * state_dict[f"blocks.{l}.ln2.w"][:, None]
#    1750 )
#    1752 if self.cfg.gated_mlp:
#    1753     state_dict[f"blocks.{l}.mlp.W_gate"] = (
#    1754         state_dict[f"blocks.{l}.mlp.W_gate"]
#    1755         * state_dict[f"blocks.{l}.ln2.w"][:, None]
#    1756     )
#
# KeyboardInterrupt:
